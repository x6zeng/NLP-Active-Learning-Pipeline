# %%
import numpy as np
import pandas as pd
import math

# %%
df_2022 = pd.read_csv('data/tweet_data_2022.csv')
df_2023 = pd.read_csv('data/tweet_data_2023.csv')

# %%
df_2022.head()
# Out:
#          date                                               text   userid_str  \
# 0  2015-09-28  I commend all of law enforcement for the secur...  156333623.0
# 1  2019-02-24  Socialist tyrant Maduro starves, tortures his ...  235312723.0
# 2  2019-02-24  Socialist tyrant Maduro starves, tortures his ...  235312723.0
# 3  2014-06-24  Inhofe: The Canadians have already had convers...   20546536.0
# 4  2015-07-14  Statement on Iran nuclear agreement. http://t....   18773159.0
#
#    status_id_str       id              name       birth term_partisanship  \
# 0   6.485341e+17  3517566          Al Green  1947-09-01          Democrat
# 1   1.099734e+18  3559992  Scott DesJarlais  1964-02-21        Republican
# 2   1.099734e+18  3559992  Scott DesJarlais  1964-02-21        Republican
# 3   4.815273e+17  3468157   James M. Inhofe  1934-11-17        Republican
# 4   6.210401e+17  3833428       Scott Perry  1962-05-27        Republican
#
# ...

# %%
df_2023.head()
# Out:
#              created_at                                             source  \
# 0  2021-08-01T14:00:00Z                                                 []
# 1  2021-08-01T14:00:02Z  [{'url': 'https://t.co/NDqkVx5XM0', 'expanded_...
# 2  2021-08-01T15:00:19Z  [{'url': 'https://t.co/qFXyobO5tk', 'expanded_...
# 3  2021-08-01T15:35:06Z                                                 []
# 4  2021-08-01T18:00:41Z  [{'url': 'https://t.co/5828hocDsr', 'expanded_...
#
#                                                 text           userid_str  \
# 0  By January 23, 2020, Wuhan was placed under qu...   996094929733652481
# 1  Anytime the radical left makes excuses for Chi...           4205133682
# 2  During Senate hearings, I often ask witnesses ...           1068481578
# 3  Stop blaming unvaccinated Americans.\n\nStart ...  1029094268542099457
# 4  Russia has a well established TRIAD: submarine...   818975124460335106
#
# ...
