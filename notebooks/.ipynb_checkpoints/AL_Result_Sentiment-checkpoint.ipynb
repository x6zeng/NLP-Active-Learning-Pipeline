# %%
import numpy as np
import pandas as pd
import math
import re
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
from scipy import stats
warnings.filterwarnings('ignore')
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Load Data

# %%
df_sentiment = pd.read_csv('sentiment_model_result.csv') #sentiment using probability
df_sentiment_comm = pd.read_csv('sentiment_committee_model_result.csv') #sentiment using committee

# %%
df_sentiment.head(2)
# Out:
#    Unnamed: 0               model_name  training_method  balance  \
# 0           1  Multinomial Naive Bayes  random_sampling     True
# 1           2  Multinomial Naive Bayes  random_sampling     True
#
#    sampling_size  sort_by_time    partition_ratio  seed_size  unlabeled_size  \
# 0              0          True  [0.1, 0.45, 0.45]         39             186
# 1              0          True  [0.5, 0.25, 0.25]        207             102
#
#    test_size  ...  accuracy  f1_micro  f1_macro  f1_weighted  precision_micro  \
# 0        192  ...     0.354     0.354     0.351        0.351            0.354
# 1        108  ...     0.583     0.583     0.579        0.579            0.583
#
#    precision_macro  precision_weighted  recall_micro  recall_macro  \
# 0            0.373               0.373         0.354         0.354
# 1            0.612               0.612         0.583         0.583
#
#    recall_weighted
# 0            0.354
# 1            0.583
#
# [2 rows x 21 columns]

# %%
df_sentiment_comm.head(2)
# Out:
#    Unnamed: 0                                       model_names  \
# 0           1  SVC, KNN, Decision Tree, Random Forest, AdaBoost
# 1           2  SVC, KNN, Decision Tree, Random Forest, AdaBoost
#
#    training_method  balance  sampling_size  sort_by_time    partition_ratio  \
# 0  random_sampling     True              0          True  [0.1, 0.45, 0.45]
# 1  random_sampling     True              0          True  [0.5, 0.25, 0.25]
#
#    seed_size  unlabeled_size  test_size  accuracy  f1_micro  f1_macro  \
# 0         39             186        192    0.2822    0.2822    0.2382
# 1        207             102        108    0.5206    0.5206    0.4974
#
#    f1_weighted  precision_micro  precision_macro  precision_weighted  \
# 0       0.2382           0.2822           0.2944              0.2944
# 1       0.4974           0.5206           0.5202              0.5202
#
#    recall_micro  recall_macro  recall_weighted
# 0        0.2822        0.2822           0.2822
# 1        0.5206        0.5206           0.5206

# %% [markdown]
# ### Data Preprocessing

# %%
feat_lst = ['model_name', 'balance', 'sort_by_time', 'learning_strategy', 'partition_ratio', 'sampling_size']
metric_lst_c = ['accuracy', 'f1_micro', 'f1_macro', 'f1_weighted', 'precision_micro', 'precision_macro', 'precision_weighted', 
                 'recall_micro', 'recall_macro', 'recall_weighted'] #(model_stats_sentiment)
sent_col = feat_lst + metric_lst_c
strategies = ['probability', 'committee']
sentiment_diff_col = ['accuracy_diff_probability', 'f1_micro_diff_probability', 'f1_macro_diff_probability', 'f1_weighted_diff_probability', 'precision_micro_diff_probability', 'precision_macro_diff_probability', 'precision_weighted_diff_probability', 
                                   'recall_micro_diff_probability', 'recall_macro_diff_probability', 'recall_weighted_diff_probability',
                                   'accuracy_diff_committee', 'f1_micro_diff_committee', 'f1_macro_diff_committee', 'f1_weighted_diff_committee', 'precision_micro_diff_committee', 'precision_macro_diff_committee', 'precision_weighted_diff_committee', 
                                   'recall_micro_diff_committee', 'recall_macro_diff_committee', 'recall_weighted_diff_committee']

# %%
def assign_learning_strategy_prob(x):
    if x == 'random_sampling':
        return 'random_sampling_probability'
    else:
        return 'active_learning_probability'
    
def assign_learning_strategy_comm(x):
    if x == 'random_sampling':
        return 'random_sampling_committee'
    else:
        return 'active_learning_committee'

# %%
df_sentiment['learning_strategy'] = df_sentiment['training_method'].apply(assign_learning_strategy_prob)
df_sentiment_comm['learning_strategy'] = df_sentiment_comm['training_method'].apply(assign_learning_strategy_comm)
df_sentiment = df_sentiment[sent_col]
df_sentiment_comm=df_sentiment_comm.rename(columns={"model_names": "model_name"})[sent_col]
sentiment = pd.concat([df_sentiment, df_sentiment_comm])

# %% [markdown]
# #### Create pivot table

# %%
sentiment_pivot = sentiment.pivot_table(metric_lst_c, ['model_name', 'balance', 'sort_by_time', 'partition_ratio', 'sampling_size'], 'learning_strategy')
sentiment_pivot = sentiment_pivot.reset_index()
sentiment_pivot.columns = [sentiment_pivot.columns.values[i][0] if i < 5 else '_'.join(sentiment_pivot.columns.values[i]) for i in range(len(sentiment_pivot.columns.values))]

for m in metric_lst_c:
    for s in strategies:
        diff_col = m + '_diff_' + s 
        al_col, rs_col = m + '_active_learning_' + s, m + '_random_sampling_' + s
        sentiment_pivot[diff_col] = sentiment_pivot[al_col] - sentiment_pivot[rs_col]
    
sentiment_stats = sentiment_pivot[[f for f in feat_lst if f != 'learning_strategy'] + sentiment_diff_col]

# %%
sentiment_corr_plot=sns.heatmap(sentiment_stats.corr())
sentiment_corr_plot
# Out:
# <AxesSubplot:>

# %%
# sns.pairplot(bucket_stats)

# %% [markdown]
# ### Measure the effect of Active Learning (One Tailed Paired T-test)

# %% [markdown]
# #### Assumptions

# %% [markdown]
# As a parametric procedure (a procedure which estimates unknown parameters), the paired sample t-test makes several assumptions. Although t-tests are quite robust, it is good practice to evaluate the degree of deviation from these assumptions in order to assess the quality of the results. In a paired sample t-test, the observations are defined as the differences between two sets of values, and each assumption refers to these differences, not the original data values. The paired sample t-test has four main assumptions:

# %% [markdown]
# - The dependent variable must be continuous (interval/ratio).
# - The observations are independent of one another.
# - The dependent variable should be approximately normally distributed.
# - The dependent variable should not contain any outliers.

# %% [markdown]
# **Level of Measurement**
#
# The paired sample t-test requires the sample data to be numeric and continuous, as it is based on the normal distribution. Continuous data can take on any value within a range (income, height, weight, etc.). The opposite of continuous data is discrete data, which can only take on a few values (Low, Medium, High, etc.). Occasionally, discrete data can be used to approximate a continuous scale, such as with Likert-type scales.
#
# **Independence**
#
# Independence of observations is usually not testable, but can be reasonably assumed if the data collection process was random without replacement. In our example, it is reasonable to assume that the participating employees are independent of one another.
#
# **Normality**
#
# To test the assumption of normality, a variety of methods are available, but the simplest is to inspect the data visually using a tool like a histogram. Real-world data are almost never perfectly normal, so this assumption can be considered reasonably met if the shape looks approximately symmetric and bell-shaped. The data in the example figure below is approximately normally distributed.

# %%
def plot_dist(df, df_col, nrows, ncols, figsize):
    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize)
    colors = ['red', 'blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'teal', 'magenta', 'cyan', 'black', 
              'maroon', 'teal', 'olive', 'salmon', 'gold', 'red', 'blue', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'teal', 'magenta', 'cyan', 'black']  
    row, col = 0, 0
    for i in range(len(df_col)):
        x = df_col[i]
        c = colors[i]
        sns.histplot(data=df, x=x, kde=True, color=c, alpha=0.5, ax=axes[row, col])
        axes[row, col].legend(labels=[x])
        if col < (ncols - 1):
            col += 1
        else:
            row += 1
            col = 0
    fig.suptitle('Histogram of Metrics Differences', fontsize=20)
    plt.show()
    
plot_dist(sentiment_stats, sentiment_diff_col, 4, 5, (22, 15))

# %% [markdown]
# **Outliers**
#
# Outliers are rare values that appear far away from the majority of the data. Outliers can bias the results and potentially lead to incorrect conclusions if not handled properly. One method for dealing with outliers is to simply remove them. However, removing data points can introduce other types of bias into the results, and potentially result in losing critical information. If outliers seem to have a lot of influence on the results, a nonparametric test such as the Wilcoxon Signed Rank Test may be appropriate to use instead. Outliers can be identified visually using a boxplot.

# %%
# fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(16, 8))
# sns.boxplot(data=bucket_stats, x='accuracy_diff_probability', color='red', ax=axes[0, 0])
# sns.boxplot(data=bucket_stats, x='f1_score_diff_probability', color='blue', ax=axes[0, 1])
# sns.boxplot(data=bucket_stats, x='precision_diff_probability', color='green', ax=axes[0, 2])
# sns.boxplot(data=bucket_stats, x='recall_diff_probability', color='orange', ax=axes[0, 3])
# sns.boxplot(data=bucket_stats, x='specificity_diff_probability', color='purple', ax=axes[0, 4])
# sns.boxplot(data=bucket_stats, x='accuracy_diff_committee', color='brown', ax=axes[1, 0])
# sns.boxplot(data=bucket_stats, x='f1_score_diff_committee', color='pink', ax=axes[1, 1])
# sns.boxplot(data=bucket_stats, x='precision_diff_committee', color='gray', ax=axes[1, 2])
# sns.boxplot(data=bucket_stats, x='recall_diff_committee', color='teal', ax=axes[1, 3])
# sns.boxplot(data=bucket_stats, x='specificity_diff_committee', color='magenta', ax=axes[1, 4])
# axes[0, 0].legend(labels=['accuracy_diff_probability'])
# axes[0, 1].legend(labels=['f1_score_diff_probability'])
# axes[0, 2].legend(labels=['precision_diff_probability'])
# axes[0, 3].legend(labels=['recall_diff_probability'])
# axes[0, 4].legend(labels=['specificity_diff_probability'])
# axes[1, 0].legend(labels=['accuracy_diff_committee'])
# axes[1, 1].legend(labels=['f1_score_diff_committee'])
# axes[1, 2].legend(labels=['precision_diff_committee'])
# axes[1, 3].legend(labels=['recall_diff_committee'])
# axes[1, 4].legend(labels=['specificity_diff_committee'])
# fig.suptitle('Boxplot of Metrics Differences', fontsize=16)
# fig.text(0.5, 0.04, 'Features', ha='center', fontsize=14)
# fig.text(0.04, 0.5, 'Values', va='center', rotation='vertical', fontsize=14)
# plt.subplots_adjust(top=0.92, bottom=0.15, left=0.1, right=0.95, hspace=0.2, wspace=0.2)
# plt.show()

# %% [markdown]
# #### Paired T-Test: Random Sampling vs Active Learning (Probability)

# %% [markdown]
# - Null Hypothesis (H0): There is no difference in the accuracy mean between random sampling and active learning (probability).
#
# - (Upper-tailed) Alternative Hypothesis (H1): The mean accuracy of active learning (probability) is greater than the mean accuracy of random sampling.

# %%
rsp = sentiment[sentiment['learning_strategy'] == 'random_sampling_probability']
alp = sentiment[sentiment['learning_strategy'] == 'active_learning_probability']

# %%
def one_side_paired_t_test(random_sampling, active_learning):
    mean_lst, std_lst, se_mean_lst, low_95_lst, df_lst, t_stats_lst, p_value_lst = [],[],[],[],[],[],[]
    for m in metric_lst_c:
        rs_m, al_m = random_sampling[m], active_learning[m]
        m = stats.ttest_rel(al_m, rs_m, alternative='greater')
        diff = np.array(al_m) - np.array(rs_m)
        mean, std, sem = np.mean(diff), np.std(diff), stats.sem(diff)
        low_95, df, t_stats, p_value = m.confidence_interval().low, m.df, m.statistic, m.pvalue
        mean_lst.append(mean)
        std_lst.append(std)
        se_mean_lst.append(sem)
        low_95_lst.append(low_95)
        df_lst.append(df)
        t_stats_lst.append(t_stats)
        p_value_lst.append(p_value)
        
    summary_stats = {'Mean': mean_lst,
                     'Standard Deviation': std_lst,
                     'Standard Error Mean': se_mean_lst,
                     'Lower Bound (95% Confidence Interval)': low_95_lst,
                     'Degree of Freedom': df_lst,
                     'T-Statistic': t_stats_lst,
                     'P-Value': p_value_lst
    }
    
    pair_t_df = pd.DataFrame(data=summary_stats, index=metric_lst_c)
    return pair_t_df

# %%
prob_pair_t = one_side_paired_t_test(rsp, alp)

# %%
prob_pair_t
# Out:
#                         Mean  Standard Deviation  Standard Error Mean  \
# accuracy            0.006454            0.035416             0.002563
# f1_micro            0.006454            0.035416             0.002563
# f1_macro            0.009891            0.039169             0.002834
# f1_weighted         0.007012            0.038059             0.002754
# precision_micro     0.006454            0.035416             0.002563
# precision_macro     0.024076            0.078010             0.005645
# precision_weighted  0.006700            0.040361             0.002920
# recall_micro        0.006454            0.035416             0.002563
# recall_macro        0.008083            0.035716             0.002584
# recall_weighted     0.006454            0.035416             0.002563
#
#                     Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                         0.002219                191
# f1_micro                                         0.002219                191
# f1_macro                                         0.005206                191
# f1_weighted                                      0.002461                191
# precision_micro                                  0.002219                191
# precision_macro                                  0.014746                191
# precision_weighted                               0.001873                191
# recall_micro                                     0.002219                191
# recall_macro                                     0.003812                191
# recall_weighted                                  0.002219                191
#
#                     T-Statistic   P-Value
# accuracy               2.518591  0.006302
# f1_micro               2.518591  0.006302
# f1_macro               3.489821  0.000300
# f1_weighted            2.546412  0.005836
# precision_micro        2.518591  0.006302
# precision_macro        4.265314  0.000016
# precision_weighted     2.294200  0.011433
# recall_micro           2.518591  0.006302
# recall_macro           3.127817  0.001018
# recall_weighted        2.518591  0.006302

# %% [markdown]
# #### Paired T-Test: Random Sampling vs Active Learning (Committee)
#
# Null Hypothesis (H0): There is no difference in the accuracy mean between random sampling and active learning (Committee).
#
# (Upper-tailed) Alternative Hypothesis (H1): The mean accuracy of active learning (Committee) is greater than the mean accuracy of random sampling.

# %%
rsc = sentiment[sentiment['learning_strategy'] == 'random_sampling_committee']
alc = sentiment[sentiment['learning_strategy'] == 'active_learning_committee']

# %%
comm_pair_t = one_side_paired_t_test(rsc, alc)

# %%
comm_pair_t
# Out:
#                         Mean  Standard Deviation  Standard Error Mean  \
# accuracy           -0.014738            0.040926             0.005970
# f1_micro           -0.014738            0.040926             0.005970
# f1_macro           -0.016046            0.045094             0.006578
# f1_weighted        -0.016138            0.045011             0.006566
# precision_micro    -0.014738            0.040926             0.005970
# precision_macro    -0.011692            0.059939             0.008743
# precision_weighted -0.017396            0.045600             0.006651
# recall_micro       -0.014738            0.040926             0.005970
# recall_macro       -0.014721            0.040946             0.005973
# recall_weighted    -0.014738            0.040926             0.005970
#
#                     Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                        -0.024754                 47
# f1_micro                                        -0.024754                 47
# f1_macro                                        -0.027083                 47
# f1_weighted                                     -0.027154                 47
# precision_micro                                 -0.024754                 47
# precision_macro                                 -0.026362                 47
# precision_weighted                              -0.028556                 47
# recall_micro                                    -0.024754                 47
# recall_macro                                    -0.024743                 47
# recall_weighted                                 -0.024754                 47
#
#                     T-Statistic   P-Value
# accuracy              -2.468738  0.991374
# f1_micro              -2.468738  0.991374
# f1_macro              -2.439427  0.990730
# f1_weighted           -2.457903  0.991141
# precision_micro       -2.468738  0.991374
# precision_macro       -1.337264  0.906214
# precision_weighted    -2.615344  0.994028
# recall_micro          -2.468738  0.991374
# recall_macro          -2.464706  0.991288
# recall_weighted       -2.468738  0.991374

# %% [markdown]
# ### Explore how different parameters affect the performance of Active Learning

# %% [markdown]
# The different settings include:
#  - **Balance**: if the labels in the dataset are balanced
#  - **Sort by time**: if the tweets are sorted by time
#  - **Partition Ratio**: the ratio of training, unlabeled, testing data
#  - **Sample Size**: number of instances drawn from the unlabeled pool

# %%
def plot_mean_diff(df, feat, row, col, fig, val):
    fig, axs = plt.subplots(row, col, figsize=fig)
    for v in val:
        subset = df[df[feat] == v]
        for i in range(10):
            sub_df = subset[[metric_lst_c[i] + '_diff_probability']]
            if i < 5:
                sns.distplot(sub_df, hist=False, kde=True, kde_kws={'linewidth': 2}, label=v, ax=axs[0][i])
            else:
                sns.distplot(sub_df, hist=False, kde=True, kde_kws={'linewidth': 2}, label=v, ax=axs[1][i-5])
    for i in range(len(axs.flat)):
        axs.flat[i].set(xlabel=metric_lst_c[i] + '_diff', ylabel='Density')
    # Move the legends outside the plot
    handles, labels = axs.flat[0].get_legend_handles_labels()
    fig.legend(handles, labels, prop={'size': 8}, title=feat.title(), loc='center right', bbox_to_anchor=(0.98, 0.5))
    fig.suptitle('Difference of Metrics Mean (Random Sampling vs. Active Learning)')
    # Hide x labels and tick labels for top plots and y ticks for right plots.
#     for ax in axs.flat:
#         ax.label_outer()
    plt.show()

# %%
metric_lst_c
# Out:
# ['accuracy',
#  'f1_micro',
#  'f1_macro',
#  'f1_weighted',
#  'precision_micro',
#  'precision_macro',
#  'precision_weighted',
#  'recall_micro',
#  'recall_macro',
#  'recall_weighted']

# %% [markdown]
# **Balance**

# %%
# Balanced
rsp_balanced = sentiment[(sentiment['learning_strategy'] == 'random_sampling_probability') & (sentiment['balance']==True)]
alp_balanced = sentiment[(sentiment['learning_strategy'] == 'active_learning_probability') & (sentiment['balance']==True)]
prob_pair_t_balanced = one_side_paired_t_test(rsp_balanced, alp_balanced)
prob_pair_t_balanced
# Out:
#                         Mean  Standard Deviation  Standard Error Mean  \
# accuracy            0.012617            0.049317             0.005060
# f1_micro            0.012617            0.049317             0.005060
# f1_macro            0.013496            0.053024             0.005440
# f1_weighted         0.013496            0.053024             0.005440
# precision_micro     0.012617            0.049317             0.005060
# precision_macro     0.010927            0.056458             0.005793
# precision_weighted  0.010927            0.056458             0.005793
# recall_micro        0.012617            0.049317             0.005060
# recall_macro        0.012617            0.049317             0.005060
# recall_weighted     0.012617            0.049317             0.005060
#
#                     Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                         0.004212                 95
# f1_micro                                         0.004212                 95
# f1_macro                                         0.004459                 95
# f1_weighted                                      0.004459                 95
# precision_micro                                  0.004212                 95
# precision_macro                                  0.001305                 95
# precision_weighted                               0.001305                 95
# recall_micro                                     0.004212                 95
# recall_macro                                     0.004212                 95
# recall_weighted                                  0.004212                 95
#
#                     T-Statistic   P-Value
# accuracy               2.493526  0.007189
# f1_micro               2.493526  0.007189
# f1_macro               2.480783  0.007434
# f1_weighted            2.480783  0.007434
# precision_micro        2.493526  0.007189
# precision_macro        1.886419  0.031146
# precision_weighted     1.886419  0.031146
# recall_micro           2.493526  0.007189
# recall_macro           2.493526  0.007189
# recall_weighted        2.493526  0.007189

# %%
# Inbalanced
rsp_inbalanced = sentiment[(sentiment['learning_strategy'] == 'random_sampling_probability') & (sentiment['balance']==False)]
alp_inbalanced = sentiment[(sentiment['learning_strategy'] == 'active_learning_probability') & (sentiment['balance']==False)]
prob_pair_t_inbalanced = one_side_paired_t_test(rsp_inbalanced, alp_inbalanced)
prob_pair_t_inbalanced
# Out:
#                         Mean  Standard Deviation  Standard Error Mean  \
# accuracy            0.000292            0.000715             0.000073
# f1_micro            0.000292            0.000715             0.000073
# f1_macro            0.006285            0.015192             0.001559
# f1_weighted         0.000529            0.001186             0.000122
# precision_micro     0.000292            0.000715             0.000073
# precision_macro     0.037225            0.092940             0.009535
# precision_weighted  0.002473            0.005892             0.000605
# recall_micro        0.000292            0.000715             0.000073
# recall_macro        0.003550            0.008836             0.000907
# recall_weighted     0.000292            0.000715             0.000073
#
#                     Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                         0.000170                 95
# f1_micro                                         0.000170                 95
# f1_macro                                         0.003696                 95
# f1_weighted                                      0.000327                 95
# precision_micro                                  0.000170                 95
# precision_macro                                  0.021386                 95
# precision_weighted                               0.001469                 95
# recall_micro                                     0.000170                 95
# recall_macro                                     0.002044                 95
# recall_weighted                                  0.000170                 95
#
#                     T-Statistic   P-Value
# accuracy               3.977759  0.000068
# f1_micro               3.977759  0.000068
# f1_macro               4.032499  0.000056
# f1_weighted            4.350008  0.000017
# precision_micro        3.977759  0.000068
# precision_macro        3.903863  0.000088
# precision_weighted     4.090738  0.000045
# recall_micro           3.977759  0.000068
# recall_macro           3.915840  0.000085
# recall_weighted        3.977759  0.000068

# %%
plot_mean_diff(df=sentiment_stats, feat='balance', row=2, col=5, fig=(20, 10), val=[True, False])

# %% [markdown]
# **Time**

# %%
# Sort by time
rsp_sort_by_time = bucket[(bucket['learning_strategy'] == 'random_sampling_probability') & (bucket['sort_by_time']==True)]
alp_sort_by_time = bucket[(bucket['learning_strategy'] == 'active_learning_probability') & (bucket['sort_by_time']==True)]
prob_pair_t_sort_by_time = one_side_paired_t_test(rsp_sort_by_time, alp_sort_by_time)
prob_pair_t_sort_by_time
# Out:
#                  Mean  Standard Deviation  Standard Error Mean  \
# accuracy     0.001215            0.008429             0.000865
# f1_score     0.000867            0.006540             0.000671
# precision    0.000688            0.011030             0.001132
# recall       0.001608            0.016224             0.001665
# specificity  0.001569            0.029634             0.003040
#
#              Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                 -0.000222                 95
# f1_score                                 -0.000248                 95
# precision                                -0.001192                 95
# recall                                   -0.001157                 95
# specificity                              -0.003482                 95
#
#              T-Statistic   P-Value
# accuracy        1.404434  0.081725
# f1_score        1.291703  0.099797
# precision       0.607541  0.272471
# recall          0.966229  0.168192
# specificity     0.515965  0.303539

# %%
# Not Sort by time
rsp_not_sort_by_time = bucket[(bucket['learning_strategy'] == 'random_sampling_probability') & (bucket['sort_by_time']==False)]
alp_not_sort_by_time = bucket[(bucket['learning_strategy'] == 'active_learning_probability') & (bucket['sort_by_time']==False)]
prob_pair_t_not_sort_by_time = one_side_paired_t_test(rsp_not_sort_by_time, alp_not_sort_by_time)
prob_pair_t_not_sort_by_time
# Out:
#                  Mean  Standard Deviation  Standard Error Mean  \
# accuracy     0.001719            0.008994             0.000923
# f1_score     0.002046            0.007401             0.000759
# precision   -0.000235            0.016555             0.001699
# recall       0.003479            0.017114             0.001756
# specificity  0.010348            0.042519             0.004362
#
#              Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                  0.000186                 95
# f1_score                                  0.000785                 95
# precision                                -0.003057                 95
# recall                                    0.000563                 95
# specificity                               0.003102                 95
#
#              T-Statistic   P-Value
# accuracy        1.862675  0.032799
# f1_score        2.694259  0.004171
# precision      -0.138599  0.554970
# recall          1.981482  0.025214
# specificity     2.372116  0.009851

# %%
plot_mean_diff(feat='sort_by_time', row=1, col=5, fig=(15, 3), val=[True, False])

# %% [markdown]
# **Partition Ratio**

# %%
# Partition Ratio = [0.1, 0.45, 0.45]
rsp_145 = bucket[(bucket['learning_strategy'] == 'random_sampling_probability') & (bucket['partition_ratio']=='[0.1, 0.45, 0.45]')]
alp_145 = bucket[(bucket['learning_strategy'] == 'active_learning_probability') & (bucket['partition_ratio']=='[0.1, 0.45, 0.45]')]
prob_pair_t_145 = one_side_paired_t_test(rsp_145, alp_145)
prob_pair_t_145
# Out:
#                  Mean  Standard Deviation  Standard Error Mean  \
# accuracy     0.001572            0.010430             0.001314
# f1_score     0.002619            0.008343             0.001051
# precision   -0.002313            0.019550             0.002463
# recall       0.007350            0.024663             0.003107
# specificity  0.005794            0.055372             0.006976
#
#              Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                 -0.000622                 63
# f1_score                                  0.000864                 63
# precision                                -0.006424                 63
# recall                                    0.002163                 63
# specificity                              -0.005852                 63
#
#              T-Statistic   P-Value
# accuracy        1.196249  0.118041
# f1_score        2.491298  0.007687
# precision      -0.938891  0.824314
# recall          2.365451  0.010549
# specificity     0.830497  0.204697

# %%
# Partition Ratio = [0.5, 0.25, 0.25]
rsp_525 = bucket[(bucket['learning_strategy'] == 'random_sampling_probability') & (bucket['partition_ratio']=='[0.5, 0.25, 0.25]')]
alp_525 = bucket[(bucket['learning_strategy'] == 'active_learning_probability') & (bucket['partition_ratio']=='[0.5, 0.25, 0.25]')]
prob_pair_t_525 = one_side_paired_t_test(rsp_525, alp_525)
prob_pair_t_525
# Out:
#                  Mean  Standard Deviation  Standard Error Mean  \
# accuracy     0.002956            0.005928             0.000747
# f1_score     0.001541            0.004328             0.000545
# precision    0.003662            0.008682             0.001094
# recall      -0.001547            0.009548             0.001203
# specificity  0.013663            0.022873             0.002882
#
#              Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                  0.001709                 63
# f1_score                                  0.000630                 63
# precision                                 0.001837                 63
# recall                                   -0.003555                 63
# specificity                               0.008852                 63
#
#              T-Statistic   P-Value
# accuracy        3.958354  0.000097
# f1_score        2.825078  0.003162
# precision       3.348435  0.000688
# recall         -1.285963  0.898419
# specificity     4.741055  0.000006

# %%
# Partition Ratio = [0.9, 0.05, 0.05]
rsp_905 = bucket[(bucket['learning_strategy'] == 'random_sampling_probability') & (bucket['partition_ratio']=='[0.9, 0.05, 0.05]')]
alp_905 = bucket[(bucket['learning_strategy'] == 'active_learning_probability') & (bucket['partition_ratio']=='[0.9, 0.05, 0.05]')]
prob_pair_t_905 = one_side_paired_t_test(rsp_905, alp_905)
prob_pair_t_905
# Out:
#                  Mean  Standard Deviation  Standard Error Mean  \
# accuracy    -0.000128            0.008911             0.001123
# f1_score     0.000209            0.007490             0.000944
# precision   -0.000672            0.010845             0.001366
# recall       0.001828            0.009850             0.001241
# specificity -0.001581            0.019528             0.002460
#
#              Lower Bound (95% Confidence Interval)  Degree of Freedom  \
# accuracy                                 -0.002002                 63
# f1_score                                 -0.001366                 63
# precision                                -0.002953                 63
# recall                                   -0.000244                 63
# specificity                              -0.005689                 63
#
#              T-Statistic   P-Value
# accuracy       -0.114122  0.545248
# f1_score        0.221887  0.412560
# precision      -0.491719  0.687687
# recall          1.473175  0.072841
# specificity    -0.642702  0.738625

# %%
plot_mean_diff(feat='partition_ratio', row=1, col=5, fig=(15, 3), val=['[0.1, 0.45, 0.45]', '[0.5, 0.25, 0.25]', '[0.9, 0.05, 0.05]'])

# %% [markdown]
# #### Sample Size

# %%
plot_mean_diff(feat='sampling_size', row=1, col=5, fig=(15, 3), val=[200, 400, 600])

# %% [markdown]
# ### Choose best settings for Active Learning

# %%
def plot_subset(df, row, col, figsize, x, hue):
    # Create grid of subplots
    fig, axes = plt.subplots(nrows=row, ncols=col, figsize=figsize)
    # Loop through subplots and create line plots
    hue_colors = {}
    for i, ax in enumerate(axes):
        y = metrics[i]+"_diff_probability"
        sns.lineplot(data=df, x=x, y=y, hue=hue, ax=ax,legend=False)
        ax.set_title(y)
        if i == 0:
            for line, name in zip(ax.lines, df[hue].unique()):
                hue_colors[name] = line.get_color()        

    # Create legend on the side
    handles = [plt.Line2D([0,0],[0,0],color=hue_colors[key]) for key in hue_colors]
    labels = list(hue_colors.keys())
    fig.legend(handles, labels, prop={'size': 8}, title=hue, loc='center right', bbox_to_anchor=(1.1, 0.5))

    # Hide x labels and tick labels for top plots and y ticks for right plots.
    for ax in axes.flat:
        ax.label_outer()

    # Adjust spacing between subplots and display final plot
    plt.tight_layout()
    plt.show()

# %% [markdown]
# **Use Inbalanced data**

# %%
plot_subset(df=bucket_stats, row=1, col=5, figsize=(15,5), x="sampling_size", hue="balance")

# %% [markdown]
# **Use not sort by time data**

# %%
bucket_stats_inb = bucket_stats[bucket_stats['balance'] == False]

# %%
plot_subset(df=bucket_stats_inb, row=1, col=5, figsize=(15,5), x="sampling_size", hue="sort_by_time")

# %%
bucket_stats_inb_nst = bucket_stats_inb[bucket_stats_inb['sort_by_time'] == False]

# %%
sns.catplot(
    x='sampling_size', 
    y='accuracy_diff_probability', 
    data=bucket_stats_inb_nst, 
    ci=None,  
    height=4,
    aspect=1,
    kind='point',
    hue='partition_ratio', 
    col='model_name', 
    col_wrap=4);

# %% [markdown]
# ### Accuracy

# %%
bucket.sort_values(by=['accuracy'], ascending=False) #More data, better result
# Out:
#                                            model_name  balance  sort_by_time  \
# 191                          Random Forest Classifier    False         False
# 173                          Random Forest Classifier    False         False
# 125                          Random Forest Classifier    False         False
# 185                          Random Forest Classifier    False         False
# 143                          Random Forest Classifier    False         False
# 233                       Logistic Regression (Ridge)    False         False
# 281                       Logistic Regression (Ridge)    False         False
# 266                       Logistic Regression (Ridge)    False          True
# 179                          Random Forest Classifier    False         False
# 218                       Logistic Regression (Ridge)    False          True
# 137                          Random Forest Classifier    False         False
# 236                       Logistic Regression (Ridge)    False          True
# 89   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 230                       Logistic Regression (Ridge)    False          True
# 374                       Logistic Regression (Lasso)    False          True
# 131                          Random Forest Classifier    False         False
# 224                       Logistic Regression (Ridge)    False          True
# 332                       Logistic Regression (Lasso)    False          True
# 368                       Logistic Regression (Lasso)    False          True
# 314                       Logistic Regression (Lasso)    False          True
# 362                       Logistic Regression (Lasso)    False          True
# 83                              Bernoulli Naive Bayes    False         False
# 380                       Logistic Regression (Lasso)    False          True
# 377                       Logistic Regression (Lasso)    False         False
# 326                       Logistic Regression (Lasso)    False          True
# 320                       Logistic Regression (Lasso)    False          True
# 41   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 329                       Logistic Regression (Lasso)    False         False
# 269                       Logistic Regression (Ridge)    False         False
# 221                       Logistic Regression (Ridge)    False         False
# 272                       Logistic Regression (Ridge)    False          True
# 190                          Random Forest Classifier    False         False
# 278                       Logistic Regression (Ridge)    False          True
# 284                       Logistic Regression (Ridge)    False          True
# 95   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 178                          Random Forest Classifier    False         False
# 35                              Bernoulli Naive Bayes    False         False
# 47   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 35   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 41                              Bernoulli Naive Bayes    False         False
# 94   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 280                       Logistic Regression (Ridge)    False         False
# 83   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 29   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 77   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 184                          Random Forest Classifier    False         False
# 88                              Bernoulli Naive Bayes    False         False
# 89                              Bernoulli Naive Bayes    False         False
# 92                              Bernoulli Naive Bayes    False          True
# 142                          Random Forest Classifier    False         False
# 376                       Logistic Regression (Lasso)    False         False
# 286                       Logistic Regression (Ridge)    False         False
# 88   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 82   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 94                              Bernoulli Naive Bayes    False         False
# 77                              Bernoulli Naive Bayes    False         False
# 275                       Logistic Regression (Ridge)    False         False
# 287                       Logistic Regression (Ridge)    False         False
# 29                              Bernoulli Naive Bayes    False         False
# 328                       Logistic Regression (Lasso)    False         False
# 136                          Random Forest Classifier    False         False
# 80                              Bernoulli Naive Bayes    False          True
# 95                              Bernoulli Naive Bayes    False         False
# 91                              Bernoulli Naive Bayes    False          True
# 277                       Logistic Regression (Ridge)    False          True
# 85                              Bernoulli Naive Bayes    False          True
# 274                       Logistic Regression (Ridge)    False         False
# 44                              Bernoulli Naive Bayes    False          True
# 130                          Random Forest Classifier    False         False
# 227                       Logistic Regression (Ridge)    False         False
# 283                       Logistic Regression (Ridge)    False          True
# 370                       Logistic Regression (Lasso)    False         False
# 226                       Logistic Regression (Ridge)    False         False
# 40   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 322                       Logistic Regression (Lasso)    False         False
# 40                              Bernoulli Naive Bayes    False         False
# 38                              Bernoulli Naive Bayes    False          True
# 86                              Bernoulli Naive Bayes    False          True
# 28                              Bernoulli Naive Bayes    False         False
# 76                              Bernoulli Naive Bayes    False         False
# 34   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 232                       Logistic Regression (Ridge)    False         False
# 46   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 172                          Random Forest Classifier    False         False
# 124                          Random Forest Classifier    False         False
# 379                       Logistic Regression (Lasso)    False          True
# 229                       Logistic Regression (Ridge)    False          True
# 32                              Bernoulli Naive Bayes    False          True
# 47                              Bernoulli Naive Bayes    False         False
# 238                       Logistic Regression (Ridge)    False         False
# 37                              Bernoulli Naive Bayes    False          True
# 268                       Logistic Regression (Ridge)    False         False
# 271                       Logistic Regression (Ridge)    False          True
# 26                              Bernoulli Naive Bayes    False          True
# 220                       Logistic Regression (Ridge)    False         False
# 279                       Logistic Regression (Ridge)    False         False
# 182                          Random Forest Classifier    False          True
# 187                          Random Forest Classifier    False          True
# 285                       Logistic Regression (Ridge)    False         False
# 265                       Logistic Regression (Ridge)    False          True
# 317                       Logistic Regression (Lasso)    False         False
# 25                              Bernoulli Naive Bayes    False          True
# 217                       Logistic Regression (Ridge)    False          True
# 74                              Bernoulli Naive Bayes    False          True
# 79                              Bernoulli Naive Bayes    False          True
# 365                       Logistic Regression (Lasso)    False         False
# 73                              Bernoulli Naive Bayes    False          True
# 323                       Logistic Regression (Lasso)    False         False
# 235                       Logistic Regression (Ridge)    False          True
# 31                              Bernoulli Naive Bayes    False          True
# 43                              Bernoulli Naive Bayes    False          True
# 316                       Logistic Regression (Lasso)    False         False
# 181                          Random Forest Classifier    False          True
# 46                              Bernoulli Naive Bayes    False         False
# 364                       Logistic Regression (Lasso)    False         False
# 134                          Random Forest Classifier    False          True
# 80   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 140                          Random Forest Classifier    False          True
# 334                       Logistic Regression (Lasso)    False         False
# 149                          Random Forest Classifier     True         False
# 71                              Bernoulli Naive Bayes     True         False
# 82                              Bernoulli Naive Bayes    False         False
# 101                          Random Forest Classifier     True         False
# 65                              Bernoulli Naive Bayes     True         False
# 34                              Bernoulli Naive Bayes    False         False
# 28   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 223                       Logistic Regression (Ridge)    False          True
# 91   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 239                       Logistic Regression (Ridge)    False         False
# 76   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 383                       Logistic Regression (Lasso)    False         False
# 188                          Random Forest Classifier    False          True
# 79   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 382                       Logistic Regression (Lasso)    False         False
# 335                       Logistic Regression (Lasso)    False         False
# 93                              Bernoulli Naive Bayes    False         False
# 86   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 128                          Random Forest Classifier    False          True
# 32   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 183                          Random Forest Classifier    False         False
# 371                       Logistic Regression (Lasso)    False         False
# 38   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 231                       Logistic Regression (Ridge)    False         False
# 325                       Logistic Regression (Lasso)    False          True
# 85   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 367                       Logistic Regression (Lasso)    False          True
# 44   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 175                          Random Forest Classifier    False          True
# 215                       Logistic Regression (Ridge)     True         False
# 373                       Logistic Regression (Lasso)    False          True
# 155                          Random Forest Classifier     True         False
# 189                          Random Forest Classifier    False         False
# 331                       Logistic Regression (Lasso)    False          True
# 361                       Logistic Regression (Lasso)    False          True
# 313                       Logistic Regression (Lasso)    False          True
# 26   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 122                          Random Forest Classifier    False          True
# 170                          Random Forest Classifier    False          True
# 74   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 237                       Logistic Regression (Ridge)    False         False
# 319                       Logistic Regression (Lasso)    False          True
# 17                              Bernoulli Naive Bayes     True         False
# 177                          Random Forest Classifier    False         False
# 31   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 92   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 381                       Logistic Regression (Lasso)    False         False
# 139                          Random Forest Classifier    False          True
# 133                          Random Forest Classifier    False          True
# 273                       Logistic Regression (Ridge)    False         False
# 87                              Bernoulli Naive Bayes    False         False
# 37   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 311                       Logistic Regression (Lasso)     True         False
# 176                          Random Forest Classifier    False          True
# 219                       Logistic Regression (Ridge)    False         False
# 127                          Random Forest Classifier    False          True
# 267                       Logistic Regression (Ridge)    False         False
# 169                          Random Forest Classifier    False          True
# 121                          Random Forest Classifier    False          True
# 225                       Logistic Regression (Ridge)    False         False
# 87   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 282                       Logistic Regression (Ridge)    False          True
# 141                          Random Forest Classifier    False         False
# 25   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 73   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 43   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 135                          Random Forest Classifier    False         False
# 81   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 359                       Logistic Regression (Lasso)     True         False
# 353                       Logistic Regression (Lasso)     True         False
# 375                       Logistic Regression (Lasso)    False         False
# 251                       Logistic Regression (Ridge)     True         False
# 39   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 45   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 93   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 234                       Logistic Regression (Ridge)    False          True
# 276                       Logistic Regression (Ridge)    False          True
# 129                          Random Forest Classifier    False         False
# 171                          Random Forest Classifier    False         False
# 123                          Random Forest Classifier    False         False
# 119                          Random Forest Classifier     True         False
# 209                       Logistic Regression (Ridge)     True         False
# 245                       Logistic Regression (Ridge)     True         False
# 341                       Logistic Regression (Lasso)     True         False
# 53                              Bernoulli Naive Bayes     True         False
# 293                       Logistic Regression (Lasso)     True         False
# 81                              Bernoulli Naive Bayes    False         False
# 5                               Bernoulli Naive Bayes     True         False
# 197                       Logistic Regression (Ridge)     True         False
# 27   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 75   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 333                       Logistic Regression (Lasso)    False         False
# 90                              Bernoulli Naive Bayes    False          True
# 107                          Random Forest Classifier     True         False
# 327                       Logistic Regression (Lasso)    False         False
# 180                          Random Forest Classifier    False          True
# 113                          Random Forest Classifier     True         False
# 203                       Logistic Regression (Ridge)     True         False
# 45                              Bernoulli Naive Bayes    False         False
# 33   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 330                       Logistic Regression (Lasso)    False          True
# 228                       Logistic Regression (Ridge)    False          True
# 263                       Logistic Regression (Ridge)     True         False
# 84                              Bernoulli Naive Bayes    False          True
# 186                          Random Forest Classifier    False          True
# 78                              Bernoulli Naive Bayes    False          True
# 174                          Random Forest Classifier    False          True
# 257                       Logistic Regression (Ridge)     True         False
# 138                          Random Forest Classifier    False          True
# 23                              Bernoulli Naive Bayes     True         False
# 39                              Bernoulli Naive Bayes    False         False
# 42                              Bernoulli Naive Bayes    False          True
# 372                       Logistic Regression (Lasso)    False          True
# 378                       Logistic Regression (Lasso)    False          True
# 52                              Bernoulli Naive Bayes     True         False
# 369                       Logistic Regression (Lasso)    False         False
# 270                       Logistic Regression (Ridge)    False          True
# 4                               Bernoulli Naive Bayes     True         False
# 59   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 11   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 42   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 126                          Random Forest Classifier    False          True
# 321                       Logistic Regression (Lasso)    False         False
# 84   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 30   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 363                       Logistic Regression (Lasso)    False         False
# 315                       Logistic Regression (Lasso)    False         False
# 33                              Bernoulli Naive Bayes    False         False
# 132                          Random Forest Classifier    False          True
# 90   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 36   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 222                       Logistic Regression (Ridge)    False          True
# 36                              Bernoulli Naive Bayes    False          True
# 366                       Logistic Regression (Lasso)    False          True
# 64                              Bernoulli Naive Bayes     True         False
# 120                          Random Forest Classifier    False          True
# 168                          Random Forest Classifier    False          True
# 30                              Bernoulli Naive Bayes    False          True
# 78   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 324                       Logistic Regression (Lasso)    False          True
# 305                       Logistic Regression (Lasso)     True         False
# 11                              Bernoulli Naive Bayes     True         False
# 23   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 318                       Logistic Regression (Lasso)    False          True
# 22                              Bernoulli Naive Bayes     True         False
# 72   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 27                              Bernoulli Naive Bayes    False         False
# 75                              Bernoulli Naive Bayes    False         False
# 16                              Bernoulli Naive Bayes     True         False
# 24   SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 17   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 167                          Random Forest Classifier     True         False
# 216                       Logistic Regression (Ridge)    False          True
# 24                              Bernoulli Naive Bayes    False          True
# 161                          Random Forest Classifier     True         False
# 264                       Logistic Regression (Ridge)    False          True
# 72                              Bernoulli Naive Bayes    False          True
# 59                              Bernoulli Naive Bayes     True         False
# 70                              Bernoulli Naive Bayes     True         False
# 10                              Bernoulli Naive Bayes     True         False
# 58                              Bernoulli Naive Bayes     True         False
# 53   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 5    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 154                          Random Forest Classifier     True         False
# 299                       Logistic Regression (Lasso)     True         False
# 2                               Bernoulli Naive Bayes     True          True
# 50                              Bernoulli Naive Bayes     True          True
# 166                          Random Forest Classifier     True         False
# 21                              Bernoulli Naive Bayes     True         False
# 312                       Logistic Regression (Lasso)    False          True
# 360                       Logistic Regression (Lasso)    False          True
# 196                       Logistic Regression (Ridge)     True         False
# 244                       Logistic Regression (Ridge)     True         False
# 214                       Logistic Regression (Ridge)     True         False
# 202                       Logistic Regression (Ridge)     True         False
# 256                       Logistic Regression (Ridge)     True         False
# 347                       Logistic Regression (Lasso)     True         False
# 22   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 112                          Random Forest Classifier     True         False
# 106                          Random Forest Classifier     True         False
# 358                       Logistic Regression (Lasso)     True         False
# 70   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 64   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 160                          Random Forest Classifier     True         False
# 118                          Random Forest Classifier     True         False
# 208                       Logistic Regression (Ridge)     True         False
# 304                       Logistic Regression (Lasso)     True         False
# 65   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 8                               Bernoulli Naive Bayes     True          True
# 310                       Logistic Regression (Lasso)     True         False
# 15                              Bernoulli Naive Bayes     True         False
# 352                       Logistic Regression (Lasso)     True         False
# 71   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 16   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 261                       Logistic Regression (Ridge)     True         False
# 250                       Logistic Regression (Ridge)     True         False
# 2    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 56                              Bernoulli Naive Bayes     True          True
# 9                               Bernoulli Naive Bayes     True         False
# 100                          Random Forest Classifier     True         False
# 148                          Random Forest Classifier     True         False
# 298                       Logistic Regression (Lasso)     True         False
# 262                       Logistic Regression (Ridge)     True         False
# 340                       Logistic Regression (Lasso)     True         False
# 292                       Logistic Regression (Lasso)     True         False
# 10   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 302                       Logistic Regression (Lasso)     True          True
# 69                              Bernoulli Naive Bayes     True         False
# 346                       Logistic Regression (Lasso)     True         False
# 296                       Logistic Regression (Lasso)     True          True
# 50   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 58   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 20                              Bernoulli Naive Bayes     True          True
# 4    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 67   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 55                              Bernoulli Naive Bayes     True          True
# 213                       Logistic Regression (Ridge)     True         False
# 146                          Random Forest Classifier     True          True
# 98                           Random Forest Classifier     True          True
# 63                              Bernoulli Naive Bayes     True         False
# 62                              Bernoulli Naive Bayes     True          True
# 68                              Bernoulli Naive Bayes     True          True
# 68   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 14                              Bernoulli Naive Bayes     True          True
# 116                          Random Forest Classifier     True          True
# 52   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 207                       Logistic Regression (Ridge)     True         False
# 350                       Logistic Regression (Lasso)     True          True
# 356                       Logistic Regression (Lasso)     True          True
# 344                       Logistic Regression (Lasso)     True          True
# 151                          Random Forest Classifier     True          True
# 13                              Bernoulli Naive Bayes     True          True
# 255                       Logistic Regression (Ridge)     True         False
# 13   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 61                              Bernoulli Naive Bayes     True          True
# 14   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 19   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 61   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 117                          Random Forest Classifier     True         False
# 165                          Random Forest Classifier     True         False
# 163                          Random Forest Classifier     True          True
# 7                               Bernoulli Naive Bayes     True          True
# 8    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 55   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 110                          Random Forest Classifier     True          True
# 56   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 159                          Random Forest Classifier     True         False
# 152                          Random Forest Classifier     True          True
# 62   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 67                              Bernoulli Naive Bayes     True          True
# 200                       Logistic Regression (Ridge)     True          True
# 357                       Logistic Regression (Lasso)     True         False
# 111                          Random Forest Classifier     True         False
# 157                          Random Forest Classifier     True          True
# 69   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 20   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 3                               Bernoulli Naive Bayes     True         False
# 259                       Logistic Regression (Ridge)     True          True
# 7    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 51                              Bernoulli Naive Bayes     True         False
# 115                          Random Forest Classifier     True          True
# 15   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 248                       Logistic Regression (Ridge)     True          True
# 63   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 153                          Random Forest Classifier     True         False
# 249                       Logistic Regression (Ridge)     True         False
# 21   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 201                       Logistic Regression (Ridge)     True         False
# 1    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 19                              Bernoulli Naive Bayes     True          True
# 49   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 1                               Bernoulli Naive Bayes     True          True
# 49                              Bernoulli Naive Bayes     True          True
# 104                          Random Forest Classifier     True          True
# 109                          Random Forest Classifier     True          True
# 103                          Random Forest Classifier     True          True
# 338                       Logistic Regression (Lasso)     True          True
# 242                       Logistic Regression (Ridge)     True          True
# 290                       Logistic Regression (Lasso)     True          True
# 194                       Logistic Regression (Ridge)     True          True
# 164                          Random Forest Classifier     True          True
# 158                          Random Forest Classifier     True          True
# 206                       Logistic Regression (Ridge)     True          True
# 9    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 105                          Random Forest Classifier     True         False
# 345                       Logistic Regression (Lasso)     True         False
# 351                       Logistic Regression (Lasso)     True         False
# 212                       Logistic Regression (Ridge)     True          True
# 253                       Logistic Regression (Ridge)     True          True
# 303                       Logistic Regression (Lasso)     True         False
# 309                       Logistic Regression (Lasso)     True         False
# 205                       Logistic Regression (Ridge)     True          True
# 247                       Logistic Regression (Ridge)     True          True
# 97                           Random Forest Classifier     True          True
# 145                          Random Forest Classifier     True          True
# 301                       Logistic Regression (Lasso)     True          True
# 241                       Logistic Regression (Ridge)     True          True
# 193                       Logistic Regression (Ridge)     True          True
# 66   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 211                       Logistic Regression (Ridge)     True          True
# 254                       Logistic Regression (Ridge)     True          True
# 260                       Logistic Regression (Ridge)     True          True
# 18                              Bernoulli Naive Bayes     True          True
# 355                       Logistic Regression (Lasso)     True          True
# 289                       Logistic Regression (Lasso)     True          True
# 337                       Logistic Regression (Lasso)     True          True
# 12                              Bernoulli Naive Bayes     True          True
# 57                              Bernoulli Naive Bayes     True         False
# 54                              Bernoulli Naive Bayes     True          True
# 297                       Logistic Regression (Lasso)     True         False
# 308                       Logistic Regression (Lasso)     True          True
# 199                       Logistic Regression (Ridge)     True          True
# 57   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 343                       Logistic Regression (Lasso)     True          True
# 243                       Logistic Regression (Ridge)     True         False
# 195                       Logistic Regression (Ridge)     True         False
# 349                       Logistic Regression (Lasso)     True          True
# 60   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 307                       Logistic Regression (Lasso)     True          True
# 162                          Random Forest Classifier     True          True
# 295                       Logistic Regression (Lasso)     True          True
# 99                           Random Forest Classifier     True         False
# 147                          Random Forest Classifier     True         False
# 114                          Random Forest Classifier     True          True
# 18   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 6                               Bernoulli Naive Bayes     True          True
# 60                              Bernoulli Naive Bayes     True          True
# 108                          Random Forest Classifier     True          True
# 150                          Random Forest Classifier     True          True
# 156                          Random Forest Classifier     True          True
# 339                       Logistic Regression (Lasso)     True         False
# 291                       Logistic Regression (Lasso)     True         False
# 66                              Bernoulli Naive Bayes     True          True
# 3    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 51   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 306                       Logistic Regression (Lasso)     True          True
# 12   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 252                       Logistic Regression (Ridge)     True          True
# 210                       Logistic Regression (Ridge)     True          True
# 258                       Logistic Regression (Ridge)     True          True
# 102                          Random Forest Classifier     True          True
# 204                       Logistic Regression (Ridge)     True          True
# 300                       Logistic Regression (Lasso)     True          True
# 354                       Logistic Regression (Lasso)     True          True
# 54   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 246                       Logistic Regression (Ridge)     True          True
# 348                       Logistic Regression (Lasso)     True          True
# 6    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 294                       Logistic Regression (Lasso)     True          True
# 198                       Logistic Regression (Ridge)     True          True
# 0                               Bernoulli Naive Bayes     True          True
# 48                              Bernoulli Naive Bayes     True          True
# 342                       Logistic Regression (Lasso)     True          True
# 336                       Logistic Regression (Lasso)     True          True
# 288                       Logistic Regression (Lasso)     True          True
# 144                          Random Forest Classifier     True          True
# 96                           Random Forest Classifier     True          True
# 192                       Logistic Regression (Ridge)     True          True
# 240                       Logistic Regression (Ridge)     True          True
# 48   SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 0    SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
#
#                learning_strategy    partition_ratio  sampling_size  accuracy  \
# 191  active_learning_probability  [0.9, 0.05, 0.05]            600    0.8610
# 173  active_learning_probability  [0.9, 0.05, 0.05]              0    0.8610
# 125  random_sampling_probability  [0.9, 0.05, 0.05]              0    0.8610
# 185  active_learning_probability  [0.9, 0.05, 0.05]            400    0.8570
# 143  random_sampling_probability  [0.9, 0.05, 0.05]            600    0.8564
# 233  random_sampling_probability  [0.9, 0.05, 0.05]            400    0.8550
# 281  active_learning_probability  [0.9, 0.05, 0.05]            400    0.8550
# 266  active_learning_probability  [0.9, 0.05, 0.05]              0    0.8550
# 179  active_learning_probability  [0.9, 0.05, 0.05]            200    0.8550
# 218  random_sampling_probability  [0.9, 0.05, 0.05]              0    0.8550
# 137  random_sampling_probability  [0.9, 0.05, 0.05]            400    0.8550
# 236  random_sampling_probability  [0.9, 0.05, 0.05]            600    0.8530
# 89     active_learning_committee  [0.9, 0.05, 0.05]            400    0.8522
# 230  random_sampling_probability  [0.9, 0.05, 0.05]            400    0.8518
# 374  active_learning_probability  [0.9, 0.05, 0.05]            400    0.8510
# 131  random_sampling_probability  [0.9, 0.05, 0.05]            200    0.8502
# 224  random_sampling_probability  [0.9, 0.05, 0.05]            200    0.8498
# 332  random_sampling_probability  [0.9, 0.05, 0.05]            600    0.8494
# 368  active_learning_probability  [0.9, 0.05, 0.05]            200    0.8490
# 314  random_sampling_probability  [0.9, 0.05, 0.05]              0    0.8490
# 362  active_learning_probability  [0.9, 0.05, 0.05]              0    0.8490
# 83   active_learning_probability  [0.9, 0.05, 0.05]            200    0.8490
# 380  active_learning_probability  [0.9, 0.05, 0.05]            600    0.8490
# 377  active_learning_probability  [0.9, 0.05, 0.05]            400    0.8490
# 326  random_sampling_probability  [0.9, 0.05, 0.05]            400    0.8482
# 320  random_sampling_probability  [0.9, 0.05, 0.05]            200    0.8482
# 41     random_sampling_committee  [0.9, 0.05, 0.05]            400    0.8478
# 329  random_sampling_probability  [0.9, 0.05, 0.05]            400    0.8474
# 269  active_learning_probability  [0.9, 0.05, 0.05]              0    0.8470
# 221  random_sampling_probability  [0.9, 0.05, 0.05]              0    0.8470
# 272  active_learning_probability  [0.9, 0.05, 0.05]            200    0.8470
# 190  active_learning_probability  [0.5, 0.25, 0.25]            600    0.8470
# 278  active_learning_probability  [0.9, 0.05, 0.05]            400    0.8470
# 284  active_learning_probability  [0.9, 0.05, 0.05]            600    0.8470
# 95     active_learning_committee  [0.9, 0.05, 0.05]            600    0.8462
# 178  active_learning_probability  [0.5, 0.25, 0.25]            200    0.8460
# 35   random_sampling_probability  [0.9, 0.05, 0.05]            200    0.8458
# 47     random_sampling_committee  [0.9, 0.05, 0.05]            600    0.8458
# 35     random_sampling_committee  [0.9, 0.05, 0.05]            200    0.8450
# 41   random_sampling_probability  [0.9, 0.05, 0.05]            400    0.8450
# 94     active_learning_committee  [0.5, 0.25, 0.25]            600    0.8446
# 280  active_learning_probability  [0.5, 0.25, 0.25]            400    0.8440
# 83     active_learning_committee  [0.9, 0.05, 0.05]            200    0.8438
# 29     random_sampling_committee  [0.9, 0.05, 0.05]              0    0.8430
# 77     active_learning_committee  [0.9, 0.05, 0.05]              0    0.8430
# 184  active_learning_probability  [0.5, 0.25, 0.25]            400    0.8430
# 88   active_learning_probability  [0.5, 0.25, 0.25]            400    0.8430
# 89   active_learning_probability  [0.9, 0.05, 0.05]            400    0.8430
# 92   active_learning_probability  [0.9, 0.05, 0.05]            600    0.8430
# 142  random_sampling_probability  [0.5, 0.25, 0.25]            600    0.8424
# 376  active_learning_probability  [0.5, 0.25, 0.25]            400    0.8420
# 286  active_learning_probability  [0.5, 0.25, 0.25]            600    0.8420
# 88     active_learning_committee  [0.5, 0.25, 0.25]            400    0.8418
# 82     active_learning_committee  [0.5, 0.25, 0.25]            200    0.8416
# 94   active_learning_probability  [0.5, 0.25, 0.25]            600    0.8410
# 77   active_learning_probability  [0.9, 0.05, 0.05]              0    0.8410
# 275  active_learning_probability  [0.9, 0.05, 0.05]            200    0.8410
# 287  active_learning_probability  [0.9, 0.05, 0.05]            600    0.8410
# 29   random_sampling_probability  [0.9, 0.05, 0.05]              0    0.8410
# 328  random_sampling_probability  [0.5, 0.25, 0.25]            400    0.8396
# 136  random_sampling_probability  [0.5, 0.25, 0.25]            400    0.8394
# 80   active_learning_probability  [0.9, 0.05, 0.05]            200    0.8390
# 95   active_learning_probability  [0.9, 0.05, 0.05]            600    0.8390
# 91   active_learning_probability  [0.5, 0.25, 0.25]            600    0.8390
# 277  active_learning_probability  [0.5, 0.25, 0.25]            400    0.8390
# 85   active_learning_probability  [0.5, 0.25, 0.25]            400    0.8390
# 274  active_learning_probability  [0.5, 0.25, 0.25]            200    0.8390
# 44   random_sampling_probability  [0.9, 0.05, 0.05]            600    0.8386
# 130  random_sampling_probability  [0.5, 0.25, 0.25]            200    0.8386
# 227  random_sampling_probability  [0.9, 0.05, 0.05]            200    0.8382
# 283  active_learning_probability  [0.5, 0.25, 0.25]            600    0.8380
# 370  active_learning_probability  [0.5, 0.25, 0.25]            200    0.8380
# 226  random_sampling_probability  [0.5, 0.25, 0.25]            200    0.8380
# 40     random_sampling_committee  [0.5, 0.25, 0.25]            400    0.8378
# 322  random_sampling_probability  [0.5, 0.25, 0.25]            200    0.8376
# 40   random_sampling_probability  [0.5, 0.25, 0.25]            400    0.8374
# 38   random_sampling_probability  [0.9, 0.05, 0.05]            400    0.8370
# 86   active_learning_probability  [0.9, 0.05, 0.05]            400    0.8370
# 28   random_sampling_probability  [0.5, 0.25, 0.25]              0    0.8370
# 76   active_learning_probability  [0.5, 0.25, 0.25]              0    0.8370
# 34     random_sampling_committee  [0.5, 0.25, 0.25]            200    0.8368
# 232  random_sampling_probability  [0.5, 0.25, 0.25]            400    0.8366
# 46     random_sampling_committee  [0.5, 0.25, 0.25]            600    0.8364
# 172  active_learning_probability  [0.5, 0.25, 0.25]              0    0.8360
# 124  random_sampling_probability  [0.5, 0.25, 0.25]              0    0.8360
# 379  active_learning_probability  [0.5, 0.25, 0.25]            600    0.8360
# 229  random_sampling_probability  [0.5, 0.25, 0.25]            400    0.8358
# 32   random_sampling_probability  [0.9, 0.05, 0.05]            200    0.8358
# 47   random_sampling_probability  [0.9, 0.05, 0.05]            600    0.8358
# 238  random_sampling_probability  [0.5, 0.25, 0.25]            600    0.8356
# 37   random_sampling_probability  [0.5, 0.25, 0.25]            400    0.8356
# 268  active_learning_probability  [0.5, 0.25, 0.25]              0    0.8350
# 271  active_learning_probability  [0.5, 0.25, 0.25]            200    0.8350
# 26   random_sampling_probability  [0.9, 0.05, 0.05]              0    0.8350
# 220  random_sampling_probability  [0.5, 0.25, 0.25]              0    0.8350
# 279  active_learning_probability  [0.1, 0.45, 0.45]            400    0.8350
# 182  active_learning_probability  [0.9, 0.05, 0.05]            400    0.8350
# 187  active_learning_probability  [0.5, 0.25, 0.25]            600    0.8350
# 285  active_learning_probability  [0.1, 0.45, 0.45]            600    0.8350
# 265  active_learning_probability  [0.5, 0.25, 0.25]              0    0.8350
# 317  random_sampling_probability  [0.9, 0.05, 0.05]              0    0.8350
# 25   random_sampling_probability  [0.5, 0.25, 0.25]              0    0.8350
# 217  random_sampling_probability  [0.5, 0.25, 0.25]              0    0.8350
# 74   active_learning_probability  [0.9, 0.05, 0.05]              0    0.8350
# 79   active_learning_probability  [0.5, 0.25, 0.25]            200    0.8350
# 365  active_learning_probability  [0.9, 0.05, 0.05]              0    0.8350
# 73   active_learning_probability  [0.5, 0.25, 0.25]              0    0.8350
# 339    0.6600     0.7450  0.5930       0.7970
# 291    0.6600     0.7450  0.5930       0.7970
# 66     0.7370     0.6480  0.8560       0.5350
# 3      0.6462     0.7654  0.5596       0.8286
# 51     0.6466     0.7542  0.5662       0.8154
# 306    0.7138     0.6610  0.7764       0.6010
# 12     0.6946     0.6828  0.7078       0.6702
# 252    0.7260     0.6480  0.8260       0.5510
# 210    0.7256     0.6474  0.8248       0.5500
# 258    0.7300     0.6420  0.8460       0.5270
# 102    0.7042     0.6624  0.7528       0.6146
# 204    0.7144     0.6436  0.8032       0.5546
# 300    0.6912     0.6594  0.7266       0.6238
# 354    0.7050     0.6440  0.7780       0.5690
# 54     0.7028     0.6506  0.7756       0.5718
# 246    0.7190     0.6300  0.8360       0.5090
# 348    0.6870     0.6520  0.7260       0.6120
# 6      0.6834     0.6544  0.7166       0.6212
# 294    0.6870     0.6458  0.7346       0.5970
# 198    0.7040     0.6270  0.8034       0.5214
# 0      0.6420     0.6700  0.6170       0.6960
# 48     0.6420     0.6700  0.6170       0.6960
# 342    0.6590     0.6420  0.6770       0.6230
# 336    0.6440     0.5910  0.7070       0.5100
# 288    0.6440     0.5910  0.7070       0.5100
# 144    0.5910     0.6080  0.5750       0.6290
# 96     0.5910     0.6080  0.5750       0.6290
# 192    0.6370     0.5690  0.7240       0.4510
# 240    0.6370     0.5690  0.7240       0.4510
# 48     0.5582     0.5862  0.5328       0.6238
# 0      0.5470     0.5778  0.5196       0.6204

# %%
bucket_stats.sort_values(by=['accuracy_diff_probability'], ascending=False) #More data, better result
# Out:
#                                            model_name  balance  sort_by_time  \
# 95                        Logistic Regression (Lasso)     True          True
# 35                              Bernoulli Naive Bayes     True         False
# 3                               Bernoulli Naive Bayes    False         False
# 73                        Logistic Regression (Lasso)     True         False
# 185                          Random Forest Classifier     True          True
# 82                        Logistic Regression (Lasso)     True         False
# 177                          Random Forest Classifier     True         False
# 137                       Logistic Regression (Ridge)     True          True
# 2                               Bernoulli Naive Bayes    False         False
# 37                              Bernoulli Naive Bayes     True          True
# 41                              Bernoulli Naive Bayes     True          True
# 139                       Logistic Regression (Ridge)     True          True
# 163                          Random Forest Classifier    False          True
# 181                          Random Forest Classifier     True          True
# 51                        Logistic Regression (Lasso)    False         False
# 146                          Random Forest Classifier    False         False
# 162                          Random Forest Classifier    False          True
# 173                          Random Forest Classifier     True         False
# 123                       Logistic Regression (Ridge)     True         False
# 75                        Logistic Regression (Lasso)     True         False
# 145                          Random Forest Classifier    False         False
# 99                        Logistic Regression (Ridge)    False         False
# 133                       Logistic Regression (Ridge)     True          True
# 67                        Logistic Regression (Lasso)    False          True
# 107                       Logistic Regression (Ridge)    False         False
# 1                               Bernoulli Naive Bayes    False         False
# 134                       Logistic Regression (Ridge)     True          True
# 175                          Random Forest Classifier     True         False
# 91                        Logistic Regression (Lasso)     True          True
# 147                          Random Forest Classifier    False         False
# 34                              Bernoulli Naive Bayes     True         False
# 7                               Bernoulli Naive Bayes    False         False
# 158                          Random Forest Classifier    False          True
# 102                       Logistic Regression (Ridge)    False         False
# 149                          Random Forest Classifier    False         False
# 129                       Logistic Regression (Ridge)     True         False
# 13                              Bernoulli Naive Bayes    False          True
# 161                          Random Forest Classifier    False          True
# 50                        Logistic Regression (Lasso)    False         False
# 110                       Logistic Regression (Ridge)    False          True
# 14                              Bernoulli Naive Bayes    False          True
# 98                        Logistic Regression (Ridge)    False         False
# 189                          Random Forest Classifier     True          True
# 103                       Logistic Regression (Ridge)    False         False
# 187                          Random Forest Classifier     True          True
# 15                              Bernoulli Naive Bayes    False          True
# 6                               Bernoulli Naive Bayes    False         False
# 186                          Random Forest Classifier     True          True
# 19                              Bernoulli Naive Bayes    False          True
# 126                       Logistic Regression (Ridge)     True         False
# 153                          Random Forest Classifier    False         False
# 169                          Random Forest Classifier     True         False
# 62                        Logistic Regression (Lasso)    False          True
# 155                          Random Forest Classifier    False         False
# 89                        Logistic Regression (Lasso)     True          True
# 151                          Random Forest Classifier    False         False
# 43                              Bernoulli Naive Bayes     True          True
# 23                              Bernoulli Naive Bayes    False          True
# 183                          Random Forest Classifier     True          True
# 111                       Logistic Regression (Ridge)    False          True
# 115                       Logistic Regression (Ridge)    False          True
# 79                        Logistic Regression (Lasso)     True         False
# 65                        Logistic Regression (Lasso)    False          True
# 150                          Random Forest Classifier    False         False
# 18                              Bernoulli Naive Bayes    False          True
# 157                          Random Forest Classifier    False          True
# 11                              Bernoulli Naive Bayes    False         False
# 9                               Bernoulli Naive Bayes    False         False
# 114                       Logistic Regression (Ridge)    False          True
# 21                              Bernoulli Naive Bayes    False          True
# 113                       Logistic Regression (Ridge)    False          True
# 70                        Logistic Regression (Lasso)    False          True
# 105                       Logistic Regression (Ridge)    False         False
# 109                       Logistic Regression (Ridge)    False          True
# 46                              Bernoulli Naive Bayes     True          True
# 30                              Bernoulli Naive Bayes     True         False
# 54                        Logistic Regression (Lasso)    False         False
# 97                        Logistic Regression (Ridge)    False         False
# 154                          Random Forest Classifier    False         False
# 166                          Random Forest Classifier    False          True
# 170                          Random Forest Classifier     True         False
# 74                        Logistic Regression (Lasso)     True         False
# 58                        Logistic Regression (Lasso)    False         False
# 61                        Logistic Regression (Lasso)    False          True
# 17                              Bernoulli Naive Bayes    False          True
# 101                       Logistic Regression (Ridge)    False         False
# 69                        Logistic Regression (Lasso)    False          True
# 59                        Logistic Regression (Lasso)    False         False
# 138                       Logistic Regression (Ridge)     True          True
# 159                          Random Forest Classifier    False          True
# 49                        Logistic Regression (Lasso)    False         False
# 53                        Logistic Regression (Lasso)    False         False
# 5                               Bernoulli Naive Bayes    False         False
# 121                       Logistic Regression (Ridge)     True         False
# 184                          Random Forest Classifier     True          True
# 116                       Logistic Regression (Ridge)    False          True
# 188                          Random Forest Classifier     True          True
# 120                       Logistic Regression (Ridge)     True         False
# 176                          Random Forest Classifier     True         False
# 172                          Random Forest Classifier     True         False
# 180                          Random Forest Classifier     True          True
# 144                          Random Forest Classifier    False         False
# 168                          Random Forest Classifier     True         False
# 164                          Random Forest Classifier    False          True
# 160                          Random Forest Classifier    False          True
# 140                       Logistic Regression (Ridge)     True          True
# 124                       Logistic Regression (Ridge)     True         False
# 128                       Logistic Regression (Ridge)     True         False
# 156                          Random Forest Classifier    False          True
# 132                       Logistic Regression (Ridge)     True          True
# 152                          Random Forest Classifier    False         False
# 136                       Logistic Regression (Ridge)     True          True
# 148                          Random Forest Classifier    False         False
# 0                               Bernoulli Naive Bayes    False         False
# 96                        Logistic Regression (Ridge)    False         False
# 112                       Logistic Regression (Ridge)    False          True
# 80                        Logistic Regression (Lasso)     True         False
# 72                        Logistic Regression (Lasso)     True         False
# 68                        Logistic Regression (Lasso)    False          True
# 64                        Logistic Regression (Lasso)    False          True
# 108                       Logistic Regression (Ridge)    False          True
# 56                        Logistic Regression (Lasso)    False         False
# 52                        Logistic Regression (Lasso)    False         False
# 48                        Logistic Regression (Lasso)    False         False
# 44                              Bernoulli Naive Bayes     True          True
# 40                              Bernoulli Naive Bayes     True          True
# 36                              Bernoulli Naive Bayes     True          True
# 32                              Bernoulli Naive Bayes     True         False
# 28                              Bernoulli Naive Bayes     True         False
# 24                              Bernoulli Naive Bayes     True         False
# 22                              Bernoulli Naive Bayes    False          True
# 20                              Bernoulli Naive Bayes    False          True
# 16                              Bernoulli Naive Bayes    False          True
# 12                              Bernoulli Naive Bayes    False          True
# 8                               Bernoulli Naive Bayes    False         False
# 4                               Bernoulli Naive Bayes    False         False
# 76                        Logistic Regression (Lasso)     True         False
# 60                        Logistic Regression (Lasso)    False          True
# 92                        Logistic Regression (Lasso)     True          True
# 88                        Logistic Regression (Lasso)     True          True
# 84                        Logistic Regression (Lasso)     True          True
# 104                       Logistic Regression (Ridge)    False         False
# 106                       Logistic Regression (Ridge)    False         False
# 100                       Logistic Regression (Ridge)    False         False
# 42                              Bernoulli Naive Bayes     True          True
# 29                              Bernoulli Naive Bayes     True         False
# 135                       Logistic Regression (Ridge)     True          True
# 71                        Logistic Regression (Lasso)    False          True
# 77                        Logistic Regression (Lasso)     True         False
# 66                        Logistic Regression (Lasso)    False          True
# 55                        Logistic Regression (Lasso)    False         False
# 78                        Logistic Regression (Lasso)     True         False
# 31                              Bernoulli Naive Bayes     True         False
# 167                          Random Forest Classifier    False          True
# 171                          Random Forest Classifier     True         False
# 10                              Bernoulli Naive Bayes    False         False
# 182                          Random Forest Classifier     True          True
# 33                              Bernoulli Naive Bayes     True         False
# 174                          Random Forest Classifier     True         False
# 141                       Logistic Regression (Ridge)     True          True
# 117                       Logistic Regression (Ridge)    False          True
# 122                       Logistic Regression (Ridge)     True         False
# 63                        Logistic Regression (Lasso)    False          True
# 47                              Bernoulli Naive Bayes     True          True
# 45                              Bernoulli Naive Bayes     True          True
# 83                        Logistic Regression (Lasso)     True         False
# 130                       Logistic Regression (Ridge)     True         False
# 118                       Logistic Regression (Ridge)    False          True
# 57                        Logistic Regression (Lasso)    False         False
# 119                       Logistic Regression (Ridge)    False          True
# 86                        Logistic Regression (Lasso)     True          True
# 143                       Logistic Regression (Ridge)     True          True
# 165                          Random Forest Classifier    False          True
# 81                        Logistic Regression (Lasso)     True         False
# 125                       Logistic Regression (Ridge)     True         False
# 190                          Random Forest Classifier     True          True
# 142                       Logistic Regression (Ridge)     True          True
# 93                        Logistic Regression (Lasso)     True          True
# 94                        Logistic Regression (Lasso)     True          True
# 178                          Random Forest Classifier     True         False
# 26                              Bernoulli Naive Bayes     True         False
# 127                       Logistic Regression (Ridge)     True         False
# 179                          Random Forest Classifier     True         False
# 87                        Logistic Regression (Lasso)     True          True
# 85                        Logistic Regression (Lasso)     True          True
# 38                              Bernoulli Naive Bayes     True          True
# 90                        Logistic Regression (Lasso)     True          True
# 27                              Bernoulli Naive Bayes     True         False
# 131                       Logistic Regression (Ridge)     True         False
# 191                          Random Forest Classifier     True          True
# 39                              Bernoulli Naive Bayes     True          True
# 25                              Bernoulli Naive Bayes     True         False
# 192  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 193  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 194  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 195  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 196  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 197  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 198  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 199  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 200  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 201  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 202  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 203  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False         False
# 204  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 205  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 206  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 207  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 208  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 209  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 210  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 211  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 212  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 213  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 214  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 215  SVC, KNN, Decision Tree, Random Forest, AdaBoost    False          True
# 216  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 217  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 218  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 219  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 220  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 221  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 222  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 223  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 224  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 225  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 226  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 227  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True         False
# 228  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 229  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 230  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 231  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 232  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 233  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 234  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 235  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 236  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 237  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 238  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
# 239  SVC, KNN, Decision Tree, Random Forest, AdaBoost     True          True
#
#        partition_ratio  sampling_size  accuracy_diff_probability  \
# 95   [0.9, 0.05, 0.05]            600                     0.0392
# 35   [0.9, 0.05, 0.05]            600                     0.0254
# 3    [0.1, 0.45, 0.45]            600                     0.0212
# 73   [0.1, 0.45, 0.45]            200                     0.0186
# 185  [0.5, 0.25, 0.25]            200                     0.0186
# 82   [0.9, 0.05, 0.05]            400                     0.0168
# 177  [0.9, 0.05, 0.05]            200                     0.0166
# 137  [0.5, 0.25, 0.25]            200                     0.0164
# 2    [0.1, 0.45, 0.45]            400                     0.0164
# 37   [0.1, 0.45, 0.45]            200                     0.0156
# 41   [0.5, 0.25, 0.25]            200                     0.0150
# 139  [0.5, 0.25, 0.25]            600                     0.0146
# 163  [0.5, 0.25, 0.25]            600                     0.0128
# 181  [0.1, 0.45, 0.45]            200                     0.0124
# 51   [0.1, 0.45, 0.45]            600                     0.0118
# 146  [0.1, 0.45, 0.45]            400                     0.0114
# 162  [0.5, 0.25, 0.25]            400                     0.0110
# 173  [0.5, 0.25, 0.25]            200                     0.0110
# 123  [0.1, 0.45, 0.45]            600                     0.0110
# 75   [0.1, 0.45, 0.45]            600                     0.0106
# 145  [0.1, 0.45, 0.45]            200                     0.0104
# 99   [0.1, 0.45, 0.45]            600                     0.0104
# 133  [0.1, 0.45, 0.45]            200                     0.0102
# 67   [0.5, 0.25, 0.25]            600                     0.0096
# 107  [0.9, 0.05, 0.05]            600                     0.0096
# 1    [0.1, 0.45, 0.45]            200                     0.0092
# 4    [0.5, 0.25, 0.25]              0                     0.0000
# 76   [0.5, 0.25, 0.25]              0                     0.0000
# 60   [0.1, 0.45, 0.45]              0                     0.0000
# 92   [0.9, 0.05, 0.05]              0                     0.0000
# 88   [0.5, 0.25, 0.25]              0                     0.0000
# 84   [0.1, 0.45, 0.45]              0                     0.0000
# 104  [0.9, 0.05, 0.05]              0                     0.0000
# 106  [0.9, 0.05, 0.05]            400                     0.0000
# 100  [0.5, 0.25, 0.25]              0                     0.0000
# 42   [0.5, 0.25, 0.25]            400                    -0.0002
# 29   [0.5, 0.25, 0.25]            200                    -0.0004
# 135  [0.1, 0.45, 0.45]            600                    -0.0004
# 71   [0.9, 0.05, 0.05]            600                    -0.0004
# 77   [0.5, 0.25, 0.25]            200                    -0.0012
# 66   [0.5, 0.25, 0.25]            400                    -0.0012
# 55   [0.5, 0.25, 0.25]            600                    -0.0014
# 78   [0.5, 0.25, 0.25]            400                    -0.0016
# 31   [0.5, 0.25, 0.25]            600                    -0.0016
# 167  [0.9, 0.05, 0.05]            600                    -0.0016
# 171  [0.1, 0.45, 0.45]            600                    -0.0018
# 10   [0.9, 0.05, 0.05]            400                    -0.0020
# 182  [0.1, 0.45, 0.45]            400                    -0.0020
# 33   [0.9, 0.05, 0.05]            200                    -0.0020
# 174  [0.5, 0.25, 0.25]            400                    -0.0022
# 141  [0.9, 0.05, 0.05]            200                    -0.0024
# 117  [0.9, 0.05, 0.05]            200                    -0.0028
# 122  [0.1, 0.45, 0.45]            400                    -0.0032
# 63   [0.1, 0.45, 0.45]            600                    -0.0034
# 47   [0.9, 0.05, 0.05]            600                    -0.0038
# 45   [0.9, 0.05, 0.05]            200                    -0.0040
# 83   [0.9, 0.05, 0.05]            600                    -0.0040
# 130  [0.9, 0.05, 0.05]            400                    -0.0042
# 118  [0.9, 0.05, 0.05]            400                    -0.0048
# 57   [0.9, 0.05, 0.05]            200                    -0.0052
# 119  [0.9, 0.05, 0.05]            600                    -0.0060
# 86   [0.1, 0.45, 0.45]            400                    -0.0062
# 143  [0.9, 0.05, 0.05]            600                    -0.0080
# 165  [0.9, 0.05, 0.05]            200                    -0.0088
# 81   [0.9, 0.05, 0.05]            200                    -0.0088
# 125  [0.5, 0.25, 0.25]            200                    -0.0092
# 190  [0.9, 0.05, 0.05]            400                    -0.0094
# 142  [0.9, 0.05, 0.05]            400                    -0.0100
# 93   [0.9, 0.05, 0.05]            200                    -0.0106
# 94   [0.9, 0.05, 0.05]            400                    -0.0116
# 178  [0.9, 0.05, 0.05]            400                    -0.0116
# 26   [0.1, 0.45, 0.45]            400                    -0.0120
# 127  [0.5, 0.25, 0.25]            600                    -0.0122
# 179  [0.9, 0.05, 0.05]            600                    -0.0144
# 87   [0.1, 0.45, 0.45]            600                    -0.0148
# 85   [0.1, 0.45, 0.45]            200                    -0.0158
# 38   [0.1, 0.45, 0.45]            400                    -0.0166
# 90   [0.5, 0.25, 0.25]            400                    -0.0166
# 27   [0.1, 0.45, 0.45]            600                    -0.0170
# 131  [0.9, 0.05, 0.05]            600                    -0.0190
# 191  [0.9, 0.05, 0.05]            600                    -0.0208
# 39   [0.1, 0.45, 0.45]            600                    -0.0226
# 25   [0.1, 0.45, 0.45]            200                    -0.0492
# 192  [0.1, 0.45, 0.45]              0                        NaN
# 193  [0.1, 0.45, 0.45]            200                        NaN
# 194  [0.1, 0.45, 0.45]            400                        NaN
# 195  [0.1, 0.45, 0.45]            600                        NaN
# 196  [0.5, 0.25, 0.25]              0                        NaN
# 197  [0.5, 0.25, 0.25]            200                        NaN
# 198  [0.5, 0.25, 0.25]            400                        NaN
# 199  [0.5, 0.25, 0.25]            600                        NaN
# 200  [0.9, 0.05, 0.05]              0                        NaN
# 201  [0.9, 0.05, 0.05]            200                        NaN
# 202  [0.9, 0.05, 0.05]            400                        NaN
# 203  [0.9, 0.05, 0.05]            600                        NaN
# 204  [0.1, 0.45, 0.45]              0                        NaN
# 205  [0.1, 0.45, 0.45]            200                        NaN
# 206  [0.1, 0.45, 0.45]            400                        NaN
# 207  [0.1, 0.45, 0.45]            600                        NaN
# 208  [0.5, 0.25, 0.25]              0                        NaN
# 209  [0.5, 0.25, 0.25]            200                        NaN
# 210  [0.5, 0.25, 0.25]            400                        NaN
# 211  [0.5, 0.25, 0.25]            600                        NaN
# 212  [0.9, 0.05, 0.05]              0                        NaN
# 213  [0.9, 0.05, 0.05]            200                        NaN
# 214  [0.9, 0.05, 0.05]            400                        NaN
# 215  [0.9, 0.05, 0.05]            600                        NaN
# 216  [0.1, 0.45, 0.45]              0                        NaN
# 217  [0.1, 0.45, 0.45]            200                        NaN
# 218  [0.1, 0.45, 0.45]            400                        NaN
# 219  [0.1, 0.45, 0.45]            600                        NaN
# 220  [0.5, 0.25, 0.25]              0                        NaN
# 221  [0.5, 0.25, 0.25]            200                        NaN
# 222  [0.5, 0.25, 0.25]            400                        NaN
# 223  [0.5, 0.25, 0.25]            600                        NaN
# 224  [0.9, 0.05, 0.05]              0                        NaN
# 225  [0.9, 0.05, 0.05]            200                        NaN
# 226  [0.9, 0.05, 0.05]            400                        NaN
# 227  [0.9, 0.05, 0.05]            600                        NaN
# 228  [0.1, 0.45, 0.45]              0                        NaN
# 229  [0.1, 0.45, 0.45]            200                        NaN
# 230  [0.1, 0.45, 0.45]            400                        NaN
# 231  [0.1, 0.45, 0.45]            600                        NaN
# 232  [0.5, 0.25, 0.25]              0                        NaN
# 233  [0.5, 0.25, 0.25]            200                        NaN
# 234  [0.5, 0.25, 0.25]            400                        NaN
# 235  [0.5, 0.25, 0.25]            600                        NaN
# 236  [0.9, 0.05, 0.05]              0                        NaN
# 237  [0.9, 0.05, 0.05]            200                        NaN
# 238  [0.9, 0.05, 0.05]            400                        NaN
# 239  [0.9, 0.05, 0.05]            600                        NaN
#
#      f1_score_diff_probability  precision_diff_probability  \
# 95                      0.0278                      0.0432
# 35                      0.0278                      0.0172
# 3                       0.0098                      0.0274
# 73                      0.0232                      0.0134
# 197              5.600000e-03                -0.0018
# 198              6.400000e-03                -0.0048
# 199              9.400000e-03                -0.0032
# 200              4.000000e-04                -0.0008
# 201             -2.600000e-03                 0.0030
# 202              2.600000e-03                 0.0026
# 203              1.600000e-03                -0.0024
# 204              2.000000e-04                 0.0012
# 205             -2.000000e-03                -0.0008
# 206              1.600000e-03                 0.0000
# 207             -4.000000e-04                -0.0022
# 208             -2.000000e-04                 0.0004
# 209              6.400000e-03                 0.0000
# 210              5.800000e-03                -0.0018
# 211              1.180000e-02                -0.0014
# 212             -8.000000e-04                 0.0000
# 213              2.200000e-03                 0.0008
# 214              4.000000e-04                 0.0008
# 215             -4.200000e-03                 0.0002
# 216             -1.120000e-02                 0.0066
# 217             -6.380000e-02                 0.0808
# 218             -6.000000e-03                 0.0082
# 219             -2.000000e-03                 0.0112
# 220             -4.600000e-03                -0.0090
# 221             -7.400000e-03                 0.0050
# 222              9.600000e-03                -0.0024
# 223             -9.200000e-03                 0.0072
# 224              0.000000e+00                 0.0020
# 225              1.200000e-03                -0.0018
# 226             -3.840000e-02                -0.0214
# 227             -3.820000e-02                -0.0306
# 228              8.400000e-03                 0.0132
# 229             -3.800000e-03                 0.0590
# 230              1.300000e-02                 0.0370
# 231              4.420000e-02                -0.0358
# 232              1.110223e-16                -0.0018
# 233              1.420000e-02                -0.0194
# 234              2.400000e-03                -0.0092
# 235              2.300000e-02                -0.0182
# 236             -7.000000e-03                 0.0054
# 237             -3.400000e-03                 0.0076
# 238             -8.600000e-03                 0.0018
# 239              1.540000e-02                 0.0016
#
#      specificity_diff_committee
# 95                          NaN
# 35                          NaN
# 3                           NaN
# 73                          NaN
# 185                         NaN
# 82                          NaN
# 177                         NaN
# 137                         NaN
# 2                           NaN
# 37                          NaN
# 41                          NaN
# 139                         NaN
# 163                         NaN
# 181                         NaN
# 51                          NaN
# 146                         NaN
# 162                         NaN
# 173                         NaN
# 123                         NaN
# 75                          NaN
# 145                         NaN
# 99                          NaN
# 133                         NaN
# 67                          NaN
# 107                         NaN
# 1                           NaN
# 134                         NaN
# 175                         NaN
# 91                          NaN
# 147                         NaN
# 34                          NaN
# 7                           NaN
# 158                         NaN
# 102                         NaN
# 149                         NaN
# 129                         NaN
# 13                          NaN
# 161                         NaN
# 50                          NaN
# 110                         NaN
# 14                          NaN
# 98                          NaN
# 189                         NaN
# 103                         NaN
# 187                         NaN
# 15                          NaN
# 6                           NaN
# 186                         NaN
# 19                          NaN
# 126                         NaN
# 153                         NaN
# 169                         NaN
# 62                          NaN
# 155                         NaN
# 89                          NaN
# 151                         NaN
# 43                          NaN
# 23                          NaN
# 183                         NaN
# 111                         NaN
# 115                         NaN
# 79                          NaN
# 65                          NaN
# 150                         NaN
# 18                          NaN
# 157                         NaN
# 11                          NaN
# 9                           NaN
# 114                         NaN
# 21                          NaN
# 113                         NaN
# 70                          NaN
# 105                         NaN
# 109                         NaN
# 46                          NaN
# 30                          NaN
# 54                          NaN
# 97                          NaN
# 154                         NaN
# 166                         NaN
# 170                         NaN
# 74                          NaN
# 58                          NaN
# 61                          NaN
# 17                          NaN
# 101                         NaN
# 69                          NaN
# 59                          NaN
# 138                         NaN
# 159                         NaN
# 49                          NaN
# 53                          NaN
# 5                           NaN
# 121                         NaN
# 184                         NaN
# 116                         NaN
# 188                         NaN
# 120                         NaN
# 176                         NaN
# 172                         NaN
# 180                         NaN
# 144                         NaN
# 168                         NaN
# 164                         NaN
# 160                         NaN
# 140                         NaN
# 124                         NaN
# 128                         NaN
# 156                         NaN
# 132                         NaN
# 152                         NaN
# 136                         NaN
# 148                         NaN
# 0                           NaN
# 96                          NaN
# 112                         NaN
# 80                          NaN
# 72                          NaN
# 68                          NaN
# 64                          NaN
# 108                         NaN
# 56                          NaN
# 52                          NaN
# 48                          NaN
# 44                          NaN
# 40                          NaN
# 36                          NaN
# 32                          NaN
# 28                          NaN
# 24                          NaN
# 22                          NaN
# 20                          NaN
# 16                          NaN
# 12                          NaN
# 8                           NaN
# 4                           NaN
# 76                          NaN
# 60                          NaN
# 92                          NaN
# 88                          NaN
# 84                          NaN
# 104                         NaN
# 106                         NaN
# 100                         NaN
# 42                          NaN
# 29                          NaN
# 135                         NaN
# 71                          NaN
# 77                          NaN
# 66                          NaN
# 55                          NaN
# 78                          NaN
# 31                          NaN
# 167                         NaN
# 171                         NaN
# 10                          NaN
# 182                         NaN
# 33                          NaN
# 174                         NaN
# 141                         NaN
# 117                         NaN
# 122                         NaN
# 63                          NaN
# 47                          NaN
# 45                          NaN
# 83                          NaN
# 130                         NaN
# 118                         NaN
# 57                          NaN
# 119                         NaN
# 86                          NaN
# 143                         NaN
# 165                         NaN
# 81                          NaN
# 125                         NaN
# 190                         NaN
# 142                         NaN
# 93                          NaN
# 94                          NaN
# 178                         NaN
# 26                          NaN
# 127                         NaN
# 179                         NaN
# 87                          NaN
# 85                          NaN
# 38                          NaN
# 90                          NaN
# 27                          NaN
# 131                         NaN
# 191                         NaN
# 39                          NaN
# 25                          NaN
# 192                     -0.0012
# 193                      0.0440
# 194                      0.0150
# 195                     -0.0086
# 196                     -0.0012
# 197                      0.0318
# 198                      0.0382
# 199                      0.0534
# 200                      0.0040
# 201                     -0.0168
# 202                      0.0116
# 203                      0.0114
# 204                      0.0010
# 205                     -0.0092
# 206                      0.0094
# 207                     -0.0018
# 208                     -0.0026
# 209                      0.0380
# 210                      0.0376
# 211                      0.0688
# 212                     -0.0040
# 213                      0.0118
# 214                      0.0002
# 215                     -0.0212
# 216                     -0.0132
# 217                     -0.1202
# 218                     -0.0080
# 219                     -0.0060
# 220                     -0.0028
# 221                     -0.0084
# 222                      0.0106
# 223                     -0.0122
# 224                      0.0002
# 225                      0.0022
# 226                     -0.0384
# 227                     -0.0368
# 228                      0.0034
# 229                     -0.0494
# 230                      0.0028
# 231                      0.0810
# 232                      0.0014
# 233                      0.0286
# 234                      0.0070
# 235                      0.0388
# 236                     -0.0138
# 237                     -0.0098
# 238                     -0.0174
# 239                      0.0290
